# %%
import pandas as pd
import numpy as np

df = pd.read_csv("cleaned_restaurant.csv")
df
# Out:
#       Unnamed: 0                                      Business_Name  \
# 0              0                American museum of the moving image
# 1              1                     Morgenstern's finest ice cream
# 2              2                     Morgenstern's finest ice cream
# 3              3                American museum of the moving image
# 4              4                American museum of the moving image
# ...          ...                                                ...
# 1619        1625                                    The mermaid inn
# 1620        1626  Marlin bar at tommy bahama and tommy bahama re...
# 1621        1627                     Manor oktoberfest forest hills
# 1622        1628                     Manor oktoberfest forest hills
# 1623        1629                     Manor oktoberfest forest hills
#
#        Boroughs         Cuisines Inspection_Date  \
# 0        Queens       Coffee/tea      01/03/2019
# ...

# %%
import os
